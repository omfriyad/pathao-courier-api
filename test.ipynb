# %% [markdown]
# ## Setup

# %%
from pathao_api import PathaoApi

# %%
client = PathaoApi(client_id = 267,
                   client_secret='wRcaibZkUdSNz2EI9ZyuXLlNrnAv0TdPUPXMnD39',
                   username='test@pathao.com',
                   password='lovePathao',
    base_url='https://hermes-api.p-stageenv.xyz')

# %% [markdown]
# ### Test Access Token

# %%
client.access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImp0aSI6IjQ5MDQ2ODBkZWZkZjJjZGMwODRjZWU2ZTM0ZjljNzEwYWNhOGE4YjZhMTFmZmE0Y2FkNmE2MWU5OTY4ZDFiMzU5NTcxZWFkODY3NjgyYTg1In0.eyJhdWQiOiIyNjciLCJqdGkiOiI0OTA0NjgwZGVmZGYyY2RjMDg0Y2VlNmUzNGY5YzcxMGFjYThhOGI2YTExZmZhNGNhZDZhNjFlOTk2OGQxYjM1OTU3MWVhZDg2NzY4MmE4NSIsImlhdCI6MTY4Mjk0MTAwMiwibmJmIjoxNjgyOTQxMDAyLCJleHAiOjE2ODMzNzMwMDIsInN1YiI6IjM1MiIsInNjb3BlcyI6W119.x7grnfiYRxQMVHq6f3v3KV3dIDKvUKDK3JeM70DUeH1-GGCV6kjTYDN_sdXSYGE-o6W6tXeoRv6C9MO6i-wka5TfO1y9IUfCCPHtbVigybDYNNW4Z7HIH18B231SY38Lw7QyllnfZs1_GDcN1g2MnZ8oZmZQ6OJOcPQp0lIAAnAPpJIhJwR0-YoyRrWv76wOPmxsL5WVssHyVDk7pkNOwZLqHJGT9FZQwsCxMM2MD8KcIqH-cDIltu4yW7oVk2cohHgvrDqi4B82Rya7btfmcbcM4h30v6CjcJd8v4sRfsGNu39DxaOTnfU_oKzuuE_42XOls2Bpxyjcy8Bd8BZ04fjCdXO1pug9ZMvmKZqOMiVP1D8K9XKbXcwCO6XOIQUku2kdTGTDvHs-M8aDfP2GpjxdGjRRdVgpzklcQjllA_8hLDn45ZHGbnbwWkDMZnoU_zctECfX3KTGoDMrqSIRs4Yasekp6OguaGTgX0qkoGpTEm_JEQxSRB8Q5rERG7m2W7EXx1UL8Y6DJ413aG71i7G2LveEFMAjz9VdVgMf9TCt04DanD2LR4RhQaURhBQN5qY4bDZb80mFWRchimh13DiD_gpsRd-GPexCe9kz2BKgC5_uK0qXxWusWDbI6nXUT_rRSpSV_b8NOpqvcmSoxjsfqHUSRJCyzTOBta5m7_s'

# %% [markdown]
# ### Test city, zone, area list

# %%
client.get_city_list()
# Out:
# {'data': [{'city_id': 32, 'city_name': 'B. Baria'},
#   {'city_id': 52, 'city_name': 'Bagerhat'},
#   {'city_id': 62, 'city_name': 'Bandarban '},
#   {'city_id': 34, 'city_name': 'Barguna '},
#   {'city_id': 17, 'city_name': 'Barisal'},
#   {'city_id': 53, 'city_name': 'Bhola'},
#   {'city_id': 9, 'city_name': 'Bogra'},
#   {'city_id': 8, 'city_name': 'Chandpur'},
#   {'city_id': 15, 'city_name': 'Chapainawabganj'},
#   {'city_id': 2, 'city_name': 'Chittagong'},
#   {'city_id': 61, 'city_name': 'Chuadanga'},
#   {'city_id': 11, 'city_name': "Cox's Bazar"},
#   {'city_id': 5, 'city_name': 'Cumilla'},
#   {'city_id': 1, 'city_name': 'Dhaka'},
#   {'city_id': 35, 'city_name': 'Dinajpur'},
#   {'city_id': 18, 'city_name': 'Faridpur'},
#   {'city_id': 6, 'city_name': 'Feni'},
#   {'city_id': 38, 'city_name': 'Gaibandha'},
#   {'city_id': 22, 'city_name': 'Gazipur'},
#   {'city_id': 56, 'city_name': 'Gopalgonj '},
#   {'city_id': 30, 'city_name': 'Habiganj'},
#   {'city_id': 41, 'city_name': 'Jamalpur'},
#   {'city_id': 19, 'city_name': 'Jashore'},
#   {'city_id': 27, 'city_name': 'Jhalokathi'},
#   {'city_id': 49, 'city_name': 'Jhenidah'},
#   {'city_id': 48, 'city_name': 'Joypurhat'},
#   {'city_id': 63, 'city_name': 'Khagrachari'},
#   {'city_id': 20, 'city_name': 'Khulna'},
#   {'city_id': 42, 'city_name': 'Kishoreganj'},
#   {'city_id': 55, 'city_name': 'Kurigram '},
#   {'city_id': 28, 'city_name': 'Kushtia'},
#   {'city_id': 40, 'city_name': 'Lakshmipur'},
#   {'city_id': 57, 'city_name': 'Lalmonirhat '},
#   {'city_id': 43, 'city_name': 'Madaripur'},
#   {'city_id': 60, 'city_name': 'Magura '},
#   {'city_id': 16, 'city_name': 'Manikganj'},
#   {'city_id': 50, 'city_name': 'Meherpur'},
#   {'city_id': 12, 'city_name': 'Moulvibazar'},
#   {'city_id': 23, 'city_name': 'Munsiganj'},
#   {'city_id': 26, 'city_name': 'Mymensingh'},
#   {'city_id': 46, 'city_name': 'Naogaon'},
#   {'city_id': 54, 'city_name': 'Narail '},
#   {'city_id': 21, 'city_name': 'Narayanganj'},
#   {'city_id': 47, 'city_name': 'Narshingdi'},
#   {'city_id': 14, 'city_name': 'Natore'},
#   {'city_id': 44, 'city_name': 'Netrakona'},
#   {'city_id': 39, 'city_name': 'Nilphamari'},
#   {'city_id': 7, 'city_name': 'Noakhali'},
#   {'city_id': 24, 'city_name': 'Pabna'},
#   {'city_id': 37, 'city_name': 'Panchagarh'},
#   {'city_id': 29, 'city_name': 'Patuakhali'},
#   {'city_id': 31, 'city_name': 'Pirojpur'},
#   {'city_id': 58, 'city_name': 'Rajbari '},
#   {'city_id': 4, 'city_name': 'Rajshahi'},
#   {'city_id': 59, 'city_name': 'Rangamati '},
#   {'city_id': 25, 'city_name': 'Rangpur'},
#   {'city_id': 51, 'city_name': 'Satkhira'},
#   {'city_id': 64, 'city_name': 'Shariatpur '},
#   {'city_id': 33, 'city_name': 'Sherpur'},
#   {'city_id': 10, 'city_name': 'Sirajganj'},
#   {'city_id': 45, 'city_name': 'Sunamganj'},
#   {'city_id': 3, 'city_name': 'Sylhet'},
#   {'city_id': 13, 'city_name': 'Tangail'},
#   {'city_id': 36, 'city_name': 'Thakurgaon '}]}

# %%
client.get_zone_list(city_id=1)
# Out:
# {'data': [{'zone_id': 1016, 'zone_name': ' Dhamrai , Savar'},
#   {'zone_id': 298, 'zone_name': '60 feet'},
#   {'zone_id': 52, 'zone_name': 'Adabor'},
#   {'zone_id': 300, 'zone_name': 'Aftab Nagar'},
#   {'zone_id': 17, 'zone_name': 'Agargaon'},
#   {'zone_id': 317, 'zone_name': 'Arambag'},
#   {'zone_id': 965, 'zone_name': 'Ashkona'},
#   {'zone_id': 55, 'zone_name': 'Azimpur'},
#   {'zone_id': 30, 'zone_name': 'Badda'},
#   {'zone_id': 312, 'zone_name': 'Baily Road'},
#   {'zone_id': 274, 'zone_name': 'Bakshi Bazar'},
#   {'zone_id': 292, 'zone_name': 'Balughat'},
#   {'zone_id': 1, 'zone_name': 'Banani'},
#   {'zone_id': 181, 'zone_name': 'Banani DOHS'},
#   {'zone_id': 24, 'zone_name': 'Banasree'},
#   {'zone_id': 250, 'zone_name': 'Bangshal'},
#   {'zone_id': 959, 'zone_name': 'Baridhara DOHS'},
#   {'zone_id': 958, 'zone_name': 'Baridhara Diplomatic Zone'},
#   {'zone_id': 960, 'zone_name': 'Baridhara J Block'},
#   {'zone_id': 303, 'zone_name': 'Bashabo '},
#   {'zone_id': 6, 'zone_name': 'Bashundhara '},
#   {'zone_id': 176, 'zone_name': 'Bawnia'},
#   {'zone_id': 981, 'zone_name': 'Beraid'},
#   {'zone_id': 964, 'zone_name': 'Boro Moghbazar'},
#   {'zone_id': 972, 'zone_name': 'Central Road'},
#   {'zone_id': 630, 'zone_name': 'ChawkBazar'},
#   {'zone_id': 966, 'zone_name': 'DIT Road'},
#   {'zone_id': 15, 'zone_name': 'Dakshinkhan'},
#   {'zone_id': 287, 'zone_name': 'Darussalam'},
#   {'zone_id': 245, 'zone_name': 'Demra'},
#   {'zone_id': 200, 'zone_name': 'Dhaka University'},
#   {'zone_id': 342, 'zone_name': 'Dhaka cantonment'},
#   {'zone_id': 62, 'zone_name': 'Dhanmondi'},
#   {'zone_id': 979, 'zone_name': 'Dholpur'},
#   {'zone_id': 23, 'zone_name': 'ECB'},
#   {'zone_id': 967, 'zone_name': 'Elephant Road'},
#   {'zone_id': 311, 'zone_name': 'Eskaton'},
#   {'zone_id': 13, 'zone_name': 'Faidabad'},
#   {'zone_id': 978, 'zone_name': 'Faridabad'},
#   {'zone_id': 46, 'zone_name': 'Farmgate'},
#   {'zone_id': 42, 'zone_name': 'Gandaria'},
#   {'zone_id': 254, 'zone_name': 'Gopibagh'},
#   {'zone_id': 308, 'zone_name': 'Goran'},
#   {'zone_id': 338, 'zone_name': 'Greenroad'},
#   {'zone_id': 35, 'zone_name': 'Gulisthan'},
#   {'zone_id': 4, 'zone_name': 'Gulshan 1'},
#   {'zone_id': 5, 'zone_name': 'Gulshan-2 '},
#   {'zone_id': 213, 'zone_name': 'Hatirpool'},
#   {'zone_id': 56, 'zone_name': 'Hazaribag'},
#   {'zone_id': 1035, 'zone_name': 'Ibrahimpur'},
#   {'zone_id': 257, 'zone_name': 'Islampur'},
#   {'zone_id': 248, 'zone_name': 'Jatrabari'},
#   {'zone_id': 61, 'zone_name': 'Jigatola'},
#   {'zone_id': 977, 'zone_name': 'Jurain'},
#   {'zone_id': 980, 'zone_name': 'Kadamtoli '},
#   {'zone_id': 63, 'zone_name': 'Kalabagan'},
#   {'zone_id': 64, 'zone_name': 'Kallyanpur'},
#   {'zone_id': 252, 'zone_name': 'Kamalapur'},
#   {'zone_id': 59, 'zone_name': 'Kathalbagan'},
#   {'zone_id': 16, 'zone_name': 'Kawla'},
#   {'zone_id': 58, 'zone_name': 'Kawran Bazar'},
#   {'zone_id': 66, 'zone_name': 'Keraniganj'},
#   {'zone_id': 29, 'zone_name': 'Khilgaon'},
#   {'zone_id': 178, 'zone_name': 'Khilkhet'},
#   {'zone_id': 177, 'zone_name': 'Kuril'},
#   {'zone_id': 260, 'zone_name': 'Lakshmibazar'},
#   {'zone_id': 57, 'zone_name': 'Lalbag'},
#   {'zone_id': 1036, 'zone_name': 'Lalkuthi'},
#   {'zone_id': 31, 'zone_name': 'Malibagh'},
#   {'zone_id': 971, 'zone_name': 'Manda '},
#   {'zone_id': 251, 'zone_name': 'Manik Nagar'},
#   {'zone_id': 337, 'zone_name': 'Manikdi'},
#   {'zone_id': 291, 'zone_name': 'Matikata'},
#   {'zone_id': 255, 'zone_name': 'Matuail'},
#   {'zone_id': 171, 'zone_name': 'Mirpur 1'},
#   {'zone_id': 19, 'zone_name': 'Mirpur 10'},
#   {'zone_id': 20, 'zone_name': 'Mirpur 11 '},
#   {'zone_id': 280, 'zone_name': 'Mirpur 12'},
#   {'zone_id': 717, 'zone_name': 'Mirpur 13'},
#   {'zone_id': 21, 'zone_name': 'Mirpur 14'},
#   {'zone_id': 22, 'zone_name': 'Mirpur 2'},
#   {'zone_id': 283, 'zone_name': 'Mirpur 6'},
#   {'zone_id': 475, 'zone_name': 'Mirpur 7'},
#   {'zone_id': 281, 'zone_name': 'Mirpur DOHS'},
#   {'zone_id': 315, 'zone_name': 'Modhubag'},
#   {'zone_id': 32, 'zone_name': 'Mogbazar'},
#   {'zone_id': 2, 'zone_name': 'Mohakhali'},
#   {'zone_id': 11, 'zone_name': 'Mohakhali DOHS'},
#   {'zone_id': 50, 'zone_name': 'Mohammadpur'},
#   {'zone_id': 233, 'zone_name': 'Monipur'},
#   {'zone_id': 34, 'zone_name': 'Motijheel'},
#   {'zone_id': 307, 'zone_name': 'Mugda'},
#   {'zone_id': 182, 'zone_name': 'Nadda'},
#   {'zone_id': 10, 'zone_name': 'Nakhalpara '},
#   {'zone_id': 266, 'zone_name': 'Narinda'},
#   {'zone_id': 259, 'zone_name': 'Nawabpur'},
#   {'zone_id': 41, 'zone_name': 'Naya Bazar'},
#   {'zone_id': 205, 'zone_name': 'Nazim Uddin Road'},
#   {'zone_id': 36, 'zone_name': 'Nazira Bazar'},
#   {'zone_id': 60, 'zone_name': 'New Elephant Road'},
#   {'zone_id': 201, 'zone_name': 'New Market'},
#   {'zone_id': 9, 'zone_name': 'Niketan'},
#   {'zone_id': 8, 'zone_name': 'Nikunja'},
#   {'zone_id': 961, 'zone_name': 'Nikunja 2'},
#   {'zone_id': 210, 'zone_name': 'Nilkhet'},
#   {'zone_id': 1009, 'zone_name': 'On-demand  transfer'},
#   {'zone_id': 18, 'zone_name': 'Paikpara'},
#   {'zone_id': 975, 'zone_name': 'Pallabi'},
#   {'zone_id': 33, 'zone_name': 'Paltan'},
#   {'zone_id': 750, 'zone_name': 'Panthapath'},
#   {'zone_id': 973, 'zone_name': 'Pirerbagh'},
#   {'zone_id': 28, 'zone_name': 'Rampura'},
#   {'zone_id': 244, 'zone_name': 'Rayerbag'},
#   {'zone_id': 974, 'zone_name': 'Rupnagar'},
#   {'zone_id': 258, 'zone_name': 'Sadarghat'},
#   {'zone_id': 65, 'zone_name': 'Savar'},
#   {'zone_id': 173, 'zone_name': 'Senpara'},
#   {'zone_id': 199, 'zone_name': 'Shahbag'},
#   {'zone_id': 957, 'zone_name': 'Shahid Nagar'},
#   {'zone_id': 180, 'zone_name': 'Shahjadpur'},
#   {'zone_id': 318, 'zone_name': 'Shajahanpur'},
#   {'zone_id': 38, 'zone_name': 'Shanir Akhra'},
#   {'zone_id': 26, 'zone_name': 'Shantinagar'},
#   {'zone_id': 302, 'zone_name': 'Shegunbagicha'},
#   {'zone_id': 1037, 'zone_name': 'Sher-e bangla Nagar'},
#   {'zone_id': 174, 'zone_name': 'Shewrapara'},
#   {'zone_id': 306, 'zone_name': 'Shiddeshwari'},
#   {'zone_id': 198, 'zone_name': 'Shyamoli'},
#   {'zone_id': 963, 'zone_name': 'South Banasree'},
#   {'zone_id': 661, 'zone_name': 'Sutrapur '},
#   {'zone_id': 3, 'zone_name': 'Tejgaon'},
#   {'zone_id': 1030, 'zone_name': 'Tejgaon Thana'},
#   {'zone_id': 282, 'zone_name': 'Tolarbag'},
#   {'zone_id': 327, 'zone_name': 'Turag'},
#   {'zone_id': 14, 'zone_name': 'UttarKhan'},
#   {'zone_id': 12, 'zone_name': 'Uttara Sector 1'},
#   {'zone_id': 941, 'zone_name': 'Uttara Sector 10'},
#   {'zone_id': 942, 'zone_name': 'Uttara Sector 11'},
#   {'zone_id': 943, 'zone_name': 'Uttara Sector 12'},
#   {'zone_id': 944, 'zone_name': 'Uttara Sector 13'},
#   {'zone_id': 945, 'zone_name': 'Uttara Sector 14'},
#   {'zone_id': 1000, 'zone_name': 'Uttara Sector 15'},
#   {'zone_id': 1001, 'zone_name': 'Uttara Sector 16'},
#   {'zone_id': 1002, 'zone_name': 'Uttara Sector 17'},
#   {'zone_id': 1003, 'zone_name': 'Uttara Sector 18'},
#   {'zone_id': 935, 'zone_name': 'Uttara Sector 3'},
#   {'zone_id': 936, 'zone_name': 'Uttara Sector 4'},
#   {'zone_id': 937, 'zone_name': 'Uttara Sector 5'},
#   {'zone_id': 939, 'zone_name': 'Uttara Sector 7'},
#   {'zone_id': 946, 'zone_name': 'Uttara Sector 8'},
#   {'zone_id': 940, 'zone_name': 'Uttara Sector 9'},
#   {'zone_id': 938, 'zone_name': 'Uttara sector 6'},
#   {'zone_id': 962, 'zone_name': 'Vatara'},
#   {'zone_id': 37, 'zone_name': 'Wari'},
#   {'zone_id': 352, 'zone_name': 'kafrul'},
#   {'zone_id': 655, 'zone_name': 'kamranggirchar'},
#   {'zone_id': 976, 'zone_name': 'shampur'}]}

# %%
client.get_area_list(zone_id=4)
# Out:
# {'data': [{'area_id': 47,
#    'area_name': ' Road 02',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 48,
#    'area_name': ' Road 03',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 49,
#    'area_name': ' Road 04',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 50,
#    'area_name': ' Road 05',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 51,
#    'area_name': ' Road 06',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 53,
#    'area_name': ' Road 08',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 54,
#    'area_name': ' Road 09',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 55,
#    'area_name': ' Road 10',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 56,
#    'area_name': ' Road 11',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 80,
#    'area_name': ' Road 116',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 81,
#    'area_name': ' Road 117',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 82,
#    'area_name': ' Road 118',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 57,
#    'area_name': ' Road 12',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 84,
#    'area_name': ' Road 120',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 85,
#    'area_name': ' Road 121',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 86,
#    'area_name': ' Road 122',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 87,
#    'area_name': ' Road 123',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 88,
#    'area_name': ' Road 124',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 89,
#    'area_name': ' Road 125',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 90,
#    'area_name': ' Road 126',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 91,
#    'area_name': ' Road 127',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 92,
#    'area_name': ' Road 128',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 93,
#    'area_name': ' Road 129',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 58,
#    'area_name': ' Road 13',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 94,
#    'area_name': ' Road 130',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 95,
#    'area_name': ' Road 131',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 96,
#    'area_name': ' Road 132',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 97,
#    'area_name': ' Road 133',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 98,
#    'area_name': ' Road 134',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 99,
#    'area_name': ' Road 135',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 100,
#    'area_name': ' Road 136',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 101,
#    'area_name': ' Road 137',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 102,
#    'area_name': ' Road 138',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 103,
#    'area_name': ' Road 139',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 59,
#    'area_name': ' Road 14',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 104,
#    'area_name': ' Road 140',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 105,
#    'area_name': ' Road 141',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 106,
#    'area_name': ' Road 142',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 60,
#    'area_name': ' Road 15',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 61,
#    'area_name': ' Road 16',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 62,
#    'area_name': ' Road 17',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 63,
#    'area_name': ' Road 18',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 64,
#    'area_name': ' Road 19',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 65,
#    'area_name': ' Road 20',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 66,
#    'area_name': ' Road 21',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 67,
#    'area_name': ' Road 22',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 68,
#    'area_name': ' Road 23',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 69,
#    'area_name': ' Road 24',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 70,
#    'area_name': ' Road 25',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 71,
#    'area_name': ' Road 26',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 72,
#    'area_name': ' Road 27',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 73,
#    'area_name': ' Road 28',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 74,
#    'area_name': ' Road 29',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 75,
#    'area_name': ' Road 30',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 76,
#    'area_name': ' Road 31',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 77,
#    'area_name': ' Road 32',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 78,
#    'area_name': ' Road 33',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16441,
#    'area_name': 'Cadet college club limited',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16442,
#    'area_name': 'DCC Market ',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16447,
#    'area_name': 'DESCO',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16449,
#    'area_name': 'Fakhruddin restaurant',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 19807,
#    'area_name': 'Gulshan 1 Aarong',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16437,
#    'area_name': 'Gulshan shooting club',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16446,
#    'area_name': 'Gulshan-1 circle',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16445,
#    'area_name': 'Jabbar Tower',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16438,
#    'area_name': 'KFC',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16448,
#    'area_name': 'Navana tower',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16439,
#    'area_name': 'Pizza hut',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 109,
#    'area_name': 'Police Plaza concord shopping mall',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 46,
#    'area_name': 'Road 01',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 52,
#    'area_name': 'Road 07',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 83,
#    'area_name': 'Road 119',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16440,
#    'area_name': 'Spectra covention centre',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16444,
#    'area_name': 'The Glass house',
#    'home_delivery_available': True,
#    'pickup_available': True},
#   {'area_id': 16443,
#    'area_name': 'Zaara convention centre',
#    'home_delivery_available': True,
#    'pickup_available': True}]}

# %% [markdown]
# ### Test get stores

# %%
client.get_stores()
# Out:
# {'message': 'Store list fetched.',
#  'type': 'success',
#  'code': 200,
#  'data': {'data': [{'store_id': 55876,
#     'store_name': 'Uttara Hub',
#     'store_address': '53 , Nawabpur Dhaka -1100',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 259,
#     'hub_id': 5,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55875,
#     'store_name': 'SSL-RK Store',
#     'store_address': 'sldfjlksdfs/fs/dfs/dfs/dfsdf',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55874,
#     'store_name': 'SSL-1 Store',
#     'store_address': 'sjfsjdfsdf,sdfs,fsd,fsd,fsd,f',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55873,
#     'store_name': 'SSL',
#     'store_address': 'Gulshan 2 Circle, Gulshan, Dhaka-1212',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55868,
#     'store_name': 'CodeTourism',
#     'store_address': 'Gulshan 2 Circle, Gulshan, Dhaka-1212',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55865,
#     'store_name': 'Rafsan',
#     'store_address': 'recipient address',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 5,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55863,
#     'store_name': 'SJA Store',
#     'store_address': 'Shobuj Shathi, Gazipur',
#     'is_active': 1,
#     'city_id': 12,
#     'zone_id': 33,
#     'hub_id': 5,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55862,
#     'store_name': 'Export Import Shop BDdfdfdfdfd',
#     'store_address': 'Export Import Shop BD',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55856,
#     'store_name': 'My store 3',
#     'store_address': 'Barisal, Bakergonj, Dudhol mou',
#     'is_active': 1,
#     'city_id': 17,
#     'zone_id': 915,
#     'hub_id': 100,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55855,
#     'store_name': 'my store 2',
#     'store_address': 'assssssssssssssssssssssssssssss',
#     'is_active': 1,
#     'city_id': 52,
#     'zone_id': 596,
#     'hub_id': 74,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55854,
#     'store_name': 'My store',
#     'store_address': 'main road, B.Baria sadar.',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55849,
#     'store_name': 'Gloria Elegance',
#     'store_address': 'Mirpur Departmental Store, Plot No 25/30, Block - G, Mirpur - 1, Zoo Road, Dhaka - 1216.',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55846,
#     'store_name': 'iiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiiii',
#     'store_address': 'House#739-742, Road#10, Avenue#4, Mirpur DOHS, Dhaka-1216',
#     'is_active': 1,
#     'city_id': 62,
#     'zone_id': 300,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55845,
#     'store_name': 'dddddddddddd',
#     'store_address': 'House#739-742, Road#10, Avenue#4, Mirpur DOHS, Dhaka-1216',
#     'is_active': 1,
#     'city_id': 34,
#     'zone_id': 300,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55844,
#     'store_name': 'vvsvssv',
#     'store_address': 'House#739-742, Road#10, Avenue#4, Mirpur DOHS, Dhaka-1216',
#     'is_active': 1,
#     'city_id': 34,
#     'zone_id': 52,
#     'hub_id': 6,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55843,
#     'store_name': 'testStoreFinal02',
#     'store_address': 'House#739-742, Road#10, Avenue#4, Mirpur DOHS, Dhaka-1216',
#     'is_active': 1,
#     'city_id': 62,
#     'zone_id': 52,
#     'hub_id': 6,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55842,
#     'store_name': 'bfbfbfbfb',
#     'store_address': 'House#739-742, Road#10, Avenue#4, Mirpur DOHS, Dhaka-1216',
#     'is_active': 1,
#     'city_id': 17,
#     'zone_id': 300,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55841,
#     'store_name': 'momagice-502',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55836,
#     'store_name': 'RBD',
#     'store_address': 'North Basabo, Khilagaon, Dhaka 1214',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 303,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55835,
#     'store_name': 'TestPathaoJoshim',
#     'store_address': 'H#22, R#44, Mirpur, Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 31,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55834,
#     'store_name': 'TestStorePartho01',
#     'store_address': 'H#33,R#44,mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 19,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55832,
#     'store_name': 'FinalTest05',
#     'store_address': 'H#33,R#44,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 17,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55831,
#     'store_name': 'TestStore99',
#     'store_address': 'H#33,R#44,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 57,
#     'hub_id': 82,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55830,
#     'store_name': 'FinalTest03',
#     'store_address': 'H#33,R#44,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 20,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55829,
#     'store_name': 'FinalTest02',
#     'store_address': 'H#33,R#44,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 19,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55828,
#     'store_name': 'finalTest01',
#     'store_address': 'H#33,R#44,Mirpur, Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55827,
#     'store_name': 'FinalStore01',
#     'store_address': 'H#33,R#44,mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 20,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55826,
#     'store_name': 'hsihsvnsvnksvnsknv',
#     'store_address': 'H#33,R#56, mirpur, Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 21,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55825,
#     'store_name': 'alibabaStore',
#     'store_address': 'House#21,road#30,Rupnagar R/A',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55824,
#     'store_name': 'TestingStoreAkkas',
#     'store_address': 'House#21,road#30,mirpur-10',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 19,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55821,
#     'store_name': 'TEST12Store',
#     'store_address': 'H#33,R#44,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55820,
#     'store_name': 'TEST11Store',
#     'store_address': 'H#33,R#33,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55819,
#     'store_name': 'TEST10STORE',
#     'store_address': 'H#33,R#33,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55818,
#     'store_name': 'Test09Store',
#     'store_address': 'H#33,R#33,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55817,
#     'store_name': 'Test08',
#     'store_address': 'H#33,R#33,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55816,
#     'store_name': 'Test07Store',
#     'store_address': 'H#33,R#33,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 19,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55815,
#     'store_name': 'Test04Store',
#     'store_address': 'H#33,R#34,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 29,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55814,
#     'store_name': 'Test03Store',
#     'store_address': 'H#33,R#34,Mirpur, Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 58,
#     'hub_id': 6,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55813,
#     'store_name': 'Test02Store',
#     'store_address': 'H#33,R#45,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 171,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55812,
#     'store_name': 'TestParthoStore01',
#     'store_address': 'H#33,R#32,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 19,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55811,
#     'store_name': 'TestStorePartho',
#     'store_address': 'H#33,R#02,Mirpur,Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 19,
#     'hub_id': 126,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55810,
#     'store_name': 'pathao test by al-amin',
#     'store_address': '28uiuyouyoy sdgsg jhgg\nhajipara\nnai',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 3,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55798,
#     'store_name': 'momagicetest2',
#     'store_address': 'Rangs Babilonya Mohakhali-1212',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55795,
#     'store_name': 'MMBD sports shop',
#     'store_address': 'sdfsdf sdf sdf sdf sdf',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55794,
#     'store_name': 'MMBD test shop',
#     'store_address': 'Dhaka range babonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55793,
#     'store_name': 'MMBD-test-1',
#     'store_address': 'Ratings Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55792,
#     'store_name': 'momagice-79',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55791,
#     'store_name': 'momagice-76',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55790,
#     'store_name': 'momagice-75',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55789,
#     'store_name': 'momagice-74',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55788,
#     'store_name': 'momagice-73',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55787,
#     'store_name': 'momagice-72',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55786,
#     'store_name': 'momagice-71',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55785,
#     'store_name': 'momagice-70',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55784,
#     'store_name': 'momagice-69',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55783,
#     'store_name': 'momagice-68',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55782,
#     'store_name': 'momagice-67',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55781,
#     'store_name': 'momagice-66',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55780,
#     'store_name': 'momagice-65',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55778,
#     'store_name': 'momagice-64',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55777,
#     'store_name': 'momagice-63',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55776,
#     'store_name': 'momagice-62',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55775,
#     'store_name': 'momagice-61',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55774,
#     'store_name': 'momagice-60',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55773,
#     'store_name': 'momagice-59',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55772,
#     'store_name': 'Export Import Shop BD1212',
#     'store_address': 'Export Import Shop BD12121212',
#     'is_active': 1,
#     'city_id': 52,
#     'zone_id': 594,
#     'hub_id': 74,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55770,
#     'store_name': 'Export Import Shop BD',
#     'store_address': 'Export Import Shop BD',
#     'is_active': 1,
#     'city_id': 52,
#     'zone_id': 156,
#     'hub_id': 74,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55765,
#     'store_name': 'momagice-56',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55764,
#     'store_name': 'momagice-55',
#     'store_address': 'Mohakhali-1212, dampara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55763,
#     'store_name': 'momagice-30',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55762,
#     'store_name': 'momagice-53',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55761,
#     'store_name': 'momagice-52',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55760,
#     'store_name': 'momagice-51',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55759,
#     'store_name': 'momagice-500',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55758,
#     'store_name': 'momagice-50',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55757,
#     'store_name': 'momagice-133',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55756,
#     'store_name': 'momagice-132',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55755,
#     'store_name': 'momagice-131',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55754,
#     'store_name': 'momagice-130',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55753,
#     'store_name': 'momagice-129',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55752,
#     'store_name': 'momagice-128',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55751,
#     'store_name': 'Nuport Store',
#     'store_address': '18 Banani, atatruk road',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55750,
#     'store_name': 'momagice-124',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55749,
#     'store_name': 'momagice-123',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55748,
#     'store_name': 'momagice-122',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55747,
#     'store_name': 'momagice-121',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55746,
#     'store_name': 'momagice-120',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55745,
#     'store_name': 'momagice-119',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55744,
#     'store_name': 'momagice-117',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55743,
#     'store_name': 'momagice-115',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55742,
#     'store_name': 'momagice-111',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55741,
#     'store_name': 'momagice-101',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55740,
#     'store_name': 'momagice-99',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55739,
#     'store_name': 'momagice-98',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55738,
#     'store_name': 'momagice-48',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55737,
#     'store_name': 'momagice-47',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55736,
#     'store_name': 'momagice-46',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55735,
#     'store_name': 'momagice-45',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55734,
#     'store_name': 'momagice-44',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55733,
#     'store_name': 'momagice-43',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55732,
#     'store_name': 'momagice-42',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55731,
#     'store_name': 'momagice-41',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55730,
#     'store_name': 'momagice-40',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55729,
#     'store_name': 'momagice-15',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55728,
#     'store_name': 'momagice-14',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55727,
#     'store_name': 'momagice-13',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55726,
#     'store_name': 'momagice-12',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55724,
#     'store_name': 'momagice-11',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55723,
#     'store_name': 'momagice-10',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55722,
#     'store_name': 'momagice-9',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55721,
#     'store_name': 'momagice-8',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55720,
#     'store_name': 'momagice-7',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55719,
#     'store_name': 'momagice-6',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55718,
#     'store_name': 'momagice-5',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55717,
#     'store_name': 'momagice-4',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55716,
#     'store_name': 'momagice-3',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55715,
#     'store_name': 'momagice-2',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55714,
#     'store_name': 'momagice-1',
#     'store_address': 'Mohakhali, Rangs Babylonia',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 4,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55713,
#     'store_name': 'sai mobile and parts 59XXrB4KwjHV',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55712,
#     'store_name': 'sai mobile and parts 59BL0GxxFweG',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55711,
#     'store_name': 'sai mobile and parts 592FdupKiTeE',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55710,
#     'store_name': 'sai mobile and parts 59bxpHfyJFcn',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55709,
#     'store_name': 'sai mobile and parts 59XcbCGQOmeD',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55708,
#     'store_name': 'sai mobile and parts 59800506199',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55707,
#     'store_name': 'sai mobile and parts 59218882091',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55706,
#     'store_name': 'sai mobile and parts 59579760518',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55705,
#     'store_name': 'sai mobile and parts 59552351415',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55704,
#     'store_name': 'sai mobile and parts 59789751462',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55703,
#     'store_name': 'sai mobile and parts 59267339203',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55702,
#     'store_name': 'sai mobile and parts 59836451791',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55701,
#     'store_name': 'sai mobile and parts 59',
#     'store_address': 'xyz,abc,ABDULLAHPUR,Akhaura,City,guj',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55700,
#     'store_name': 'Dhaka Store 5199sjsj',
#     'store_address': 'house-24, road-11,sector-6\nUttara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 185,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55697,
#     'store_name': 'd',
#     'store_address': 'dhakaddddddddddddddddd',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55682,
#     'store_name': 'hello codeboxr grocery shop',
#     'store_address': 'hello codeboxr grocery shop',
#     'is_active': 1,
#     'city_id': 52,
#     'zone_id': 594,
#     'hub_id': 74,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55681,
#     'store_name': 'TEst Shop',
#     'store_address': 'asdas asdasdasd',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 63,
#     'hub_id': 6,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55680,
#     'store_name': 'Test Shop',
#     'store_address': 'Flat 6h, Dilara Tower, 77 Bir Uttam CR Dutta Road',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 59,
#     'hub_id': 82,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55659,
#     'store_name': 'Test wow',
#     'store_address': 'testtest teaer eteastetret',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 727,
#     'hub_id': 52,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55658,
#     'store_name': 'Hazi Taiyob Ali Fruits Shop1',
#     'store_address': 'Flat 6h, Dilara Tower, , 77 Bir Uttam CR Dutta Road',
#     'is_active': 1,
#     'city_id': 62,
#     'zone_id': 714,
#     'hub_id': 42,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55657,
#     'store_name': 'Hazi Taiyob Ali Fruits Shop',
#     'store_address': 'Tinkona Pukurpar, Cinema Hall road, Habiganj',
#     'is_active': 1,
#     'city_id': 62,
#     'zone_id': 714,
#     'hub_id': 42,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55656,
#     'store_name': 'Shorotbou1',
#     'store_address': 'Jobed Ali Road, Kachijhuli, Mymensingh Sadar',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55655,
#     'store_name': 'Shorotbou',
#     'store_address': 'Jobed Ali Road, Kachijhuli, Mymensingh Sadar, 3 No word, Mymensingh, Mymensingh City Corporation',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55654,
#     'store_name': 'Uttom Medical',
#     'store_address': 'Botrish, zilla smoroni school er moor,ward no 9, kishoreganj pourosova',
#     'is_active': 1,
#     'city_id': 42,
#     'zone_id': 144,
#     'hub_id': 37,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55652,
#     'store_name': 'TEST STORE',
#     'store_address': 'RainKhola, Mirpur-2, Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 65,
#     'hub_id': 80,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55625,
#     'store_name': 'd45',
#     'store_address': 'Flat 6h, Dilara Tower, , 77 Bir Uttam CR Dutta Road',
#     'is_active': 1,
#     'city_id': 62,
#     'zone_id': 166,
#     'hub_id': 42,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55608,
#     'store_name': 'Shanta Manipuri Handicraft',
#     'store_address': 'Ramsagar, Manipuri Para, Sreemangal, Moulvibazar',
#     'is_active': 1,
#     'city_id': 54,
#     'zone_id': 158,
#     'hub_id': 67,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55604,
#     'store_name': 'Jakir V Store',
#     'store_address': 'Futani Bazer, Thakurgaon Sador, Thakurgaon, Rangpur',
#     'is_active': 1,
#     'city_id': 34,
#     'zone_id': 135,
#     'hub_id': 69,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55603,
#     'store_name': 'Shop One',
#     'store_address': '5/234, Dhaka, Bangladesh',
#     'is_active': 1,
#     'city_id': 52,
#     'zone_id': 594,
#     'hub_id': 74,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55602,
#     'store_name': 'hallow',
#     'store_address': 'katiadi ttessddererer',
#     'is_active': 1,
#     'city_id': 34,
#     'zone_id': 933,
#     'hub_id': 69,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55601,
#     'store_name': '1235121',
#     'store_address': 'testfdfdddddddddddd',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 728,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55600,
#     'store_name': '123512',
#     'store_address': 'testfdfdddddddddddd',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 728,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55598,
#     'store_name': 'Shop Title',
#     'store_address': 'Addresst One Bir Uttam CR Dutta Road',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 300,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55597,
#     'store_name': 'Nayan Shoes test 1',
#     'store_address': 'Thakurakona Bazar, 3 no. Ward, Thakurakona Union, Netrakona Sadar, Netrakona, Mymensingh',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55596,
#     'store_name': 'Nayan Shoes test',
#     'store_address': 'Thakurakona Bazar, 3 no. Ward, Thakurakona Union, Netrakona Sadar, Netrakona, Mymensingh',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55595,
#     'store_name': 'Nayan Shoesd1w',
#     'store_address': 'Thakurakona Bazar, 3 no. Ward, Thakurakona Union, Netrakona Sadar, Netrakona, Mymensingh',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55594,
#     'store_name': 'Nayan Shoesd1',
#     'store_address': 'Thakurakona Bazar, 3 no. Ward, Thakurakona Union, Netrakona Sadar, Netrakona, Mymensingh',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55593,
#     'store_name': 'Nayan Shoesd',
#     'store_address': 'Thakurakona Bazar, 3 no. Ward, Thakurakona Union, Netrakona Sadar, Netrakona, Mymensingh',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55592,
#     'store_name': 'Nayan Shoes',
#     'store_address': 'Thakurakona Bazar, 3 no. Ward, Thakurakona Union, Netrakona Sadar, Netrakona, Mymensingh',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 546,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55588,
#     'store_name': 'test personwewewe1',
#     'store_address': 'testtest teaer eteastetret',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 727,
#     'hub_id': 52,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55587,
#     'store_name': 'test personwewewe',
#     'store_address': 'testtest teaer eteastetret',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 727,
#     'hub_id': 52,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55585,
#     'store_name': 'test',
#     'store_address': 'Rampura dhaka bangladesh',
#     'is_active': 1,
#     'city_id': 21,
#     'zone_id': 121,
#     'hub_id': 13,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55584,
#     'store_name': 'Sundoritoma Store 152',
#     'store_address': 'house-24, road-11,sector-6\nUttara',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 185,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55581,
#     'store_name': 'Test store10',
#     'store_address': 'testtest teaer eteastetret',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 727,
#     'hub_id': 52,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55580,
#     'store_name': 'Test store1',
#     'store_address': 'testtest teaer eteastetret',
#     'is_active': 1,
#     'city_id': 32,
#     'zone_id': 728,
#     'hub_id': 47,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55579,
#     'store_name': 'myshoptt',
#     'store_address': 'Aluhjhjhjhjhjhjhjhjhjhjhjhjhjhjh',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55578,
#     'store_name': 'ICT Bangla',
#     'store_address': 'lalmatia block e 5/3',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 24,
#     'hub_id': 4,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 55577,
#     'store_name': 'Arnob',
#     'store_address': '183/2 North Ibrahimpur Dhaka',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 21,
#     'hub_id': 3,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 11045,
#     'store_name': 'Mehedi test',
#     'store_address': 'Sector-3, Rode-14, Uttara-1230',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 935,
#     'hub_id': 2,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 11044,
#     'store_name': 'Amit Logistic ltd test',
#     'store_address': 'Sector-14, Rode-14, Uttara-1230',
#     'is_active': 1,
#     'city_id': 2,
#     'zone_id': 945,
#     'hub_id': 2,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 11043,
#     'store_name': 'Edesh logistics ltd',
#     'store_address': 'Sector-13, Rode-14, Uttara-1230',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 944,
#     'hub_id': 2,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 11028,
#     'store_name': 'test store',
#     'store_address': 'safd asdf asdf asdfasdfasdfasdfasd fasdfasd f 1',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False},
#    {'store_id': 11026,
#     'store_name': 'Logistic Company E-desh',
#     'store_address': '12 Gausul Azam Avinue, Uttara-13, Dhaka,Bangladesh',
#     'is_active': 1,
#     'city_id': 1,
#     'zone_id': 1,
#     'hub_id': 1,
#     'is_default_store': False,
#     'is_default_return_store': False}],
#   'total': 171,
#   'current_page': 1,
#   'per_page': 1000,
#   'total_in_page': 171,
#   'last_page': 1,
#   'path': 'http://hermes-api.p-stageenv.xyz/aladdin/api/v1/stores',
#   'to': 171,
#   'from': 1,
#   'last_page_url': 'http://hermes-api.p-stageenv.xyz/aladdin/api/v1/stores?page=1',
#   'first_page_url': 'http://hermes-api.p-stageenv.xyz/aladdin/api/v1/stores?page=1'}}

# %% [markdown]
# ### Test delivery cost calculator

# %%
client.get_delivery_cost(city_id=1, zone_id=4, delivery_type=48, item_type='2', store_id='55876')
# Out:
# {'price': 60,
#  'discount': 0,
#  'promo_discount': 0,
#  'plan_id': 39,
#  'cod_enabled': 0,
#  'cod_percentage': 0,
#  'additional_charge': 0}
